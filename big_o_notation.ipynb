# %%
# Title your chart "Big O Notation"
# Label your x axis "Elements"
# Label your y axis "Operations"
# Label your curves or make a legend for the curves
# Use LaTex notation where possible

y1[i] = (x[i] + 1)
y2 = np.zeros(len(x))
for i in range(len(x)):
    y2[i] = np.log(x[i])
y3 = x
y4 = x / np.log(x)


plt.figure(figsize = (6,6))
plt.suptitle('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')

plt.subplot(221)
plt.plot(x, y1,color = 'r', ls = '--')
plt.title('O(1)')

plt.subplot(222)
plt.plot(x, y2,color = 'r', ls = '--', marker = '^')
plt.title('O(log n)')

plt.subplot(223)
plt.plot(x, y3,color = 'g', ls = '--', marker = 'o')
plt.title('O(n)')

plt.subplot(224)
plt.plot(x, y4,color = 'm', ls = '--', marker = 'v')
plt.title('O(n log n)')


plt.show()
# Out:
# /var/folders/l4/9qx5m7ds6n5ffgt96477s8gr0000gn/T/ipykernel_72087/3034095866.py:10: RuntimeWarning: divide by zero encountered in log
#   y2[i] = np.log(x[i])
# /var/folders/l4/9qx5m7ds6n5ffgt96477s8gr0000gn/T/ipykernel_72087/3034095866.py:12: RuntimeWarning: divide by zero encountered in log
#   y4 = x / np.log(x)
# /var/folders/l4/9qx5m7ds6n5ffgt96477s8gr0000gn/T/ipykernel_72087/3034095866.py:12: RuntimeWarning: divide by zero encountered in divide
#   y4 = x / np.log(x)
# /var/folders/l4/9qx5m7ds6n5ffgt96477s8gr0000gn/T/ipykernel_72087/3034095866.py:20: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(221)

# %%
y1 = x**2
y2 = 2**x
y3 = x
y4 = x**x

plt.figure(figsize = (6,6))
plt.suptitle('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')

plt.subplot(221)
plt.plot(x, y5,color = 'g', ls = '--', marker = 'o')
plt.title('O(n^2)')

plt.subplot(222)
plt.plot(x, y6,color = 'g', ls = '--', marker = 'o')
plt.title('O(2^n)')

plt.subplot(223)
plt.plot(x, y7,color = 'g', ls = '--', marker = 'o')
plt.title('O(n!)')

plt.subplot(224)
plt.plot(x, y8,color = 'g', ls = '--', marker = 'o')
plt.title('O(n^n)')


plt.show()
# Out:
# /var/folders/l4/9qx5m7ds6n5ffgt96477s8gr0000gn/T/ipykernel_72087/2378628302.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(221)
