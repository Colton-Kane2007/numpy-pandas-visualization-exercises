# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import math
from random import randint
import random

# %%
# Use seaborn's load_dataset function to load the iris database to answer the following questions:
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# What does the distribution of petal lengths look like?
sns.histplot(data=iris, x='petal_length')
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
# Is there a relationship between petal length and petal width?
sns.scatterplot(data=iris, x='petal_length', y='petal_width')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
# Would it be reasonable to predict species based on sepal width and sepal length? For this, 
# you'll visualize two numeric columns through the lense of a categorical column.
graph_one = sns.relplot(data=iris, x='sepal_width', y='sepal_length', col='species')
graph_one

# %%
# Which features would be best used to predict species?
graph_two = sns.relplot(data=iris, x='petal_width', y='petal_length', col='species')
graph_two
# petal length and petal width

# %%
a = sns.load_dataset('anscombe')
a
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# Load the anscombe dataset from seaborn. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?
a.groupby(a.dataset).describe()
#Plot the x and y values from the anscombe data. Each dataset should be in a separate column.
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.
sns.relplot(data=a, x='x', y='y', col='dataset')

# %%
from pydataset import data

# %%
# Load the InsectSprays dataset from pydataset and read it's documentation. 
insect = data('InsectSprays')
insect
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A
# 11     14     A
# 12     13     A
# 13     11     B
# 14     17     B
# 15     21     B
# 16     11     B
# 17     16     B
# 18     14     B
# 19     17     B
# 20     17     B
# 21     19     B
# 22     21     B
# 23      7     B
# 24     13     B
# 25      0     C
# 26      1     C
# 27      7     C
# 28      2     C
# 29      3     C
# 30      1     C
# 31      2     C
# 32      1     C
# 33      3     C
# 34      0     C
# 35      1     C
# 36      4     C
# 37      3     D
# 38      5     D
# 39     12     D
# 40      6     D
# 41      4     D
# 42      3     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      5     D
# 47      2     D
# 48      4     D
# 49      3     E
# 50      5     E
# 51      3     E
# 52      5     E
# 53      3     E
# 54      6     E
# ...

# %%
# Load the InsectSprays dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.
sns.boxplot(data=insect, x='count', y='spray')
# Out:
# <Axes: xlabel='count', ylabel='spray'>

# %%
# Load the swiss dataset from pydataset and read it's documentation. Create visualizations to answer the following questions:
swiss = data('swiss')
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
# Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. 
# (Choose a cutoff point for what constitutes catholic)
swiss['is_catholic'] = swiss.Catholic > 50.0

# %%
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
# Does whether or not a province is Catholic influence fertility?
swiss[swiss['is_catholic']==True].mean() == swiss[swiss['is_catholic']==False].mean()
# yes
# Out:
# Fertility           False
# Agriculture         False
# Examination         False
# Education           False
# Catholic            False
# Infant.Mortality    False
# is_catholic         False
# dtype: bool

# %%
# What measure correlates most strongly with fertility?
sns.pairplot(swiss)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
# examination

# %%
# Load the chipotle dataset from SQL, create a bar chart that shows the 4 most popular items and the revenue produced by each.
url = 'mysql+pymysql://robinson_2285:7UNuickyqxVrGk0vKJPTEF2fy6Qpg1Dg@data.codeup.com/chipotle'
query = '''SELECT * FROM orders'''
df = pd.read_sql(query, url)
df
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
df.item_price = df['item_price'].str.replace('$', '').astype(float)

# %%
da = df.groupby('item_name')[['quantity']].sum().sort_values(by=['quantity'], ascending=False).head(4)
da
# Out:
#                      quantity
# item_name
# Chicken Bowl              761
# Chicken Burrito           591
# Chips and Guacamole       506
# Steak Burrito             386

# %%
da = df.groupby('item_name').quantity.sum().nlargest(4)
da
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Name: quantity, dtype: int64

# %%
#db = df.groupby('item_name').item_price.sum().sort_values(ascending=False).head(4)
#db

# %%
db = df.groupby('item_name').item_price.sum()#.sort_values(ascending=False).head(4)
db
# Out:
# item_name
# 6 Pack Soft Drink                         356.95
# Barbacoa Bowl                             672.36
# Barbacoa Burrito                          894.75
# Barbacoa Crispy Tacos                     120.21
# Barbacoa Salad Bowl                       106.40
# Barbacoa Soft Tacos                       250.46
# Bottled Water                             302.56
# Bowl                                       29.60
# Burrito                                    44.40
# Canned Soda                               137.34
# Canned Soft Drink                         438.75
# Carnitas Bowl                             736.71
# Carnitas Burrito                          597.83
# Carnitas Crispy Tacos                      77.96
# Carnitas Salad                              8.99
# Carnitas Salad Bowl                        66.34
# Carnitas Soft Tacos                       375.94
# Chicken Bowl                             7342.73
# Chicken Burrito                          5575.82
# ...

# %%
df_merged = pd.merge(da, db, on='item_name', how='inner')
df_merged = df_merged.reset_index()
df_merged
# Out:
#              item_name  quantity  item_price
# 0         Chicken Bowl       761     7342.73
# 1      Chicken Burrito       591     5575.82
# 2  Chips and Guacamole       506     2201.04
# 3        Steak Burrito       386     3851.43

# %% [markdown]
# # create a bar chart that shows the 4 most popular items and the revenue produced by each.
# sns.barplot(data=df_merged, x='item_name', y='item_price')

# %%
sns.barplot(data=df_merged, x='item_name', y='item_price')
# Out:
# <Axes: xlabel='item_name', ylabel='item_price'>

# %%
# Load the sleepstudy dataset from pydataset and read it's documentation. 
sleep = data('sleepstudy')
sleep
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 179  369.1417     8      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
# Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.
sns.lineplot(data=sleep, x='Subject', y='Reaction', estimator=np.mean)
# Out:
# <Axes: xlabel='Subject', ylabel='Reaction'>
